# %% [markdown]
# # Adverse Hospital Events in California:
# This dataset comes from California's Office of Statewide Health Planning and Development (OSHPD). It contains data collected on 7 adverse events that can occur during hospitalization:
# retained surgical item or unretrieved device fragment, iatrogenic pneumothorax, central venous catheter-related blood stream infection, postoperative wound dehiscence, accidental puncture or laceration, transfusion reaction, and perioperative hemorrhage or hematoma.
#
# We will be slicing this data in 3 ways to be able to analyze it.
#
# **1. High-Level Statewide View**
#
# **2. Analysis by Counties**
#
# **3. Mapping the Events**
#
# My aim is to gain insight on the types of preventable events, their prevalence, and which counties have the highest rates.

# %% [markdown]
# # Data Cleaning:
# First we'll see what we're working with and identify any opportunities for cleaning.

# %%
# Importing packages and loading data.

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

adv = pd.read_csv('../input/adverse-hospital-events-in-california/ca-oshpd-adveventhospitalizationspsi-county2005-2015q3.csv')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# First look at the data.

adv
# Out:
#       Year     County  PSI                                     PSIDescription  \
# 0     2005  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 1     2006  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 2     2007  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 3     2008  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 4     2009  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# ...    ...        ...  ...                                                ...
# 4538  2011       Yuba   27               Perioperative Hemorrhage or Hematoma
# 4539  2012       Yuba   27               Perioperative Hemorrhage or Hematoma
# 4540  2013       Yuba   27               Perioperative Hemorrhage or Hematoma
# 4541  2014       Yuba   27               Perioperative Hemorrhage or Hematoma
# 4542  2015       Yuba   27               Perioperative Hemorrhage or Hematoma
#
#      Count    Population  ObsRate
# 0     321    26,447,738      1.21
# 1     341    26,679,904      1.28
# 2     353    26,935,982      1.31
# 3     346    27,272,108      1.27
# 4     308    27,630,962      1.11
# ...    ...           ...      ...
# 4538   16        51,791     30.89
# 4539   22        52,301     42.06
# 4540   24        52,770     45.48
# 4541   15        54,942     27.30
# 4542   16        40,517     39.49
#
# [4543 rows x 7 columns]

# %%
# Reformatting STATEWIDE rows to match formatting of our counties.

adv['County'] = adv['County'].replace('STATEWIDE', 'Statewide')

# %%
# Dropping two counties with missing data.

adv = adv[adv.County != 'Alpine']
adv = adv[adv.County != 'Sierra']

# %% [markdown]
# From later analysis it was discovered Alpine and Sierra (the two lowest populated counties in California) have missing data in certain years. We'll drop them from our analysis so that we don't skew results when comparing by year.

# %%
# Creating a df without "Statewide" to compare counties quickly.

adv_county = adv[adv.County != 'Statewide']

# Isolating statewide for our high-level analysis.

adv_statewide = adv[adv.County == 'Statewide']

# %%
# Viewing our new county df.

adv_county.head(1)
# Out:
#     Year   County  PSI                                     PSIDescription  \
# 11  2005  Alameda   21  Retained Surgical Item or Unretrieved Device F...
#
#    Count   Population  ObsRate
# 11   18    1,102,068      1.63

# %% [markdown]
# We will mainly be making use of the **ObsRate** column for our analysis. This shows the count per 100,000 population, and will help us to better see counties where more adverse events are occuring per population. Otherwise high-population counties like *Los Angeles* would appear as higher on our totals although their rate might be lower.

# %% [markdown]
# # Statewide Analysis:
#
# First, we'll begin with some high-level statewide analysis to get a grasp on the total rate of these events in California.

# %%
# Grouping by Year and summing ObsRate.

advtimestate = adv_statewide.groupby(['Year', 'County'])[['ObsRate']] \
               .sum() \
               .reset_index() \
               .sort_values(['County', 'Year'])

# Plotting.

fig = px.line(advtimestate, x='Year', y='ObsRate')

# Layout adjustments.

fig.update_layout(title='Adverse Events Timeline - Statewide', xaxis_title ='', 
                  yaxis_title = 'Count per 100K Population', showlegend=False)

fig.show()
# Out:
# <div>
#
#
#             <div id="1c769474-8a02-4493-9685-202aa74f9638" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1c769474-8a02-4493-9685-202aa74f9638")) {
#                     Plotly.newPlot(
#                         '1c769474-8a02-4493-9685-202aa74f9638',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Year=%{x}<br>ObsRate=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [99.15, 97.89999999999999, 94.69999999999999, 85.0, 79.15, 76.42, 70.12, 64.06, 56.660000000000004, 50.510000000000005, 45.769999999999996], "yaxis": "y"}],
#                         {"height": 600, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, ...

# %% [markdown]
# From our line chart above we can see that the rate of adverse events in California has greatly decreased from *2005-2015*.  In fact, it  has more than **halved** since *2005*.

# %%
# Grouping the data by Year & Event and summing ObsRate.

advt = adv_statewide.groupby(['Year', 'PSIDescription', 'PSI'])[['ObsRate']] \
       .sum() \
       .reset_index() \
       .sort_values(['PSIDescription', 'Year'])

# Plotting.

fig = px.line(advt, x='Year', y='ObsRate', color='PSIDescription', 
              color_discrete_sequence=px.colors.qualitative.Dark24)

# Layout adjustments.

fig.update_layout(title='Adverse Events Timeline by Description', xaxis_title ='', 
                  yaxis_title = 'Count per 100K Population')
                         
fig.for_each_trace(lambda t: t.update(name=t.name.replace("PSIDescription=", "")))

fig.show()
# Out:
# <div>
#
#
#             <div id="0a0d744d-7ced-4338-8873-bb8f9f87fcc2" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0a0d744d-7ced-4338-8873-bb8f9f87fcc2")) {
#                     Plotly.newPlot(
#                         '0a0d744d-7ced-4338-8873-bb8f9f87fcc2',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "PSIDescription=Accidental Puncture or Laceration<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "PSIDescription=Accidental Puncture or Laceration", "line": {"color": "#2E91E5", "dash": "solid"}, "mode": "lines", "name": "Accidental Puncture or Laceration", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [32.96, 33.26, 33.03, 31.14, 27.95, 27.73, 25.93, 24.18, 20.82, 16.67, 14.65], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "PSIDescription=Central Venous Catheter-Related Blood Stream Infection<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "PSIDescription=Central Venous Catheter-Related Blood Stream Infection", "line": {"color": "#E15F99", "dash": "solid"}, "mode": "lines", "name": "Central Venous Catheter-Related Blood Stream Infection", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [22.78, 21.7, 19.66, 11.85, 11.42, 10.18, 7.75, 4.43, 4.1, 4.05, 3.61], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "PSIDescription=Iatrogenic Pneumothorax<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "PSIDescription=Iatrogenic Pneumothorax", "line": {"color": "#1CA71C", "dash": "solid"}, "mode": "lines", "name": "Iatrogenic Pneumothorax", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [6.13, 5.88, 6.04, 5.8, 5.46, 5.64, 5.07, 5.1, 4.44, 4.19, 4.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "PSIDescription=Perioperative Hemorrhage or Hematoma<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "PSIDescription=Perioperative Hemorrhage or Hematoma", "line": {"color": "#FB0D0D", "dash": "solid"}, "mode": "lines", "name": "Perioperative Hemorrhage or Hematoma", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [34.37, 34.12, 32.97, 33.37, 31.77, 30.51, 28.9, 28.05, 25.23, 23.65, 21.68], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "PSIDescription=Postoperative Wound Dehiscence<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "PSIDescription=Postoperative Wound Dehiscence", "line": {"color": "#DA16FF", "dash": "solid"}, "mode": "lines", "name": "Postoperative Wound Dehiscence", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [1.63, 1.59, 1.64, 1.53, 1.41, 1.3, 1.29, 1.16, 1.12, 1.09, 1.08], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "PSIDescription=Retained Surgical Item or Unretrieved Device Fragment<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "PSIDescription=Retained Surgical Item or Unretrieved Device Fragment", "line": {"color": "#222A2A", "dash": "solid"}, "mode": "lines", "name": "Retained Surgical Item or Unretrieved Device Fragment", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [1.21, 1.28, 1.31, 1.27, 1.11, 1.04, 1.07, 1.04, 0.9, 0.81, 0.71], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "PSIDescription=Transfusion Reaction<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "PSIDescription=Transfusion Reaction", "line": {"color": "#B68100", "dash": "solid"}, "mode": "lines", "name": "Transfusion Reaction", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [0.07, 0.07, 0.05, 0.04, 0.03, 0.02, 0.11, 0.1, 0.05, 0.05, 0.04], "yaxis": "y"}],
#                         {"height": 600, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{

# %% [markdown]
# We can see from  the chart above that **Perioperative Hemorrhage / Hematoma** and **Accidental Puncture / Laceration** occur on a significantly higher basis than our other adverse events. **Transfusion Reaction** has a *very* low Obs Rate (it is important to note that there is less population receiving transfusions compared to the opportunities for the other events). **Retained Surgical Item** and **Postoperative Wound Dehiscence** also happen on a low rate.

# %%
# Plotting.

fig = px.box(adv_statewide, x='PSIDescription', y='ObsRate', color='PSIDescription',
            color_discrete_sequence=px.colors.qualitative.Dark24)

# Layout adjustments.

fig.update_layout(title='Adverse Events by Type', yaxis_title='Count per 100K Population', 
                  height=700, showlegend=False)

fig.for_each_trace(lambda t: t.update(name=t.name.replace("PSIDescription=", "")))

fig.show()
# Out:
# <div>
#
#
#             <div id="b355b6df-f15c-46fb-b039-becc47fca78a" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b355b6df-f15c-46fb-b039-becc47fca78a")) {
#                     Plotly.newPlot(
#                         'b355b6df-f15c-46fb-b039-becc47fca78a',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "PSIDescription=%{x}<br>ObsRate=%{y}", "legendgroup": "PSIDescription=Retained Surgical Item or Unretrieved Device Fragment", "marker": {"color": "#2E91E5"}, "name": "Retained Surgical Item or Unretrieved Device Fragment", "notched": false, "offsetgroup": "PSIDescription=Retained Surgical Item or Unretrieved Device Fragment", "orientation": "v", "showlegend": true, "type": "box", "x": ["Retained Surgical Item or Unretrieved Device Fragment", "Retained Surgical Item or Unretrieved Device Fragment", "Retained Surgical Item or Unretrieved Device Fragment", "Retained Surgical Item or Unretrieved Device Fragment", "Retained Surgical Item or Unretrieved Device Fragment", "Retained Surgical Item or Unretrieved Device Fragment", "Retained Surgical Item or Unretrieved Device Fragment", "Retained Surgical Item or Unretrieved Device Fragment", "Retained Surgical Item or Unretrieved Device Fragment", "Retained Surgical Item or Unretrieved Device Fragment", "Retained Surgical Item or Unretrieved Device Fragment"], "x0": " ", "xaxis": "x", "y": [1.21, 1.28, 1.31, 1.27, 1.11, 1.04, 1.07, 1.04, 0.9, 0.81, 0.71], "y0": " ", "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "PSIDescription=%{x}<br>ObsRate=%{y}", "legendgroup": "PSIDescription=Iatrogenic Pneumothorax", "marker": {"color": "#E15F99"}, "name": "Iatrogenic Pneumothorax", "notched": false, "offsetgroup": "PSIDescription=Iatrogenic Pneumothorax", "orientation": "v", "showlegend": true, "type": "box", "x": ["Iatrogenic Pneumothorax", "Iatrogenic Pneumothorax", "Iatrogenic Pneumothorax", "Iatrogenic Pneumothorax", "Iatrogenic Pneumothorax", "Iatrogenic Pneumothorax", "Iatrogenic Pneumothorax", "Iatrogenic Pneumothorax", "Iatrogenic Pneumothorax", "Iatrogenic Pneumothorax", "Iatrogenic Pneumothorax"], "x0": " ", "xaxis": "x", "y": [6.13, 5.88, 6.04, 5.8, 5.46, 5.64, 5.07, 5.1, 4.44, 4.19, 4.0], "y0": " ", "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "PSIDescription=%{x}<br>ObsRate=%{y}", "legendgroup": "PSIDescription=Central Venous Catheter-Related Blood Stream Infection", "marker": {"color": "#1CA71C"}, "name": "Central Venous Catheter-Related Blood Stream Infection", "notched": false, "offsetgroup": "PSIDescription=Central Venous Catheter-Related Blood Stream Infection", "orientation": "v", "showlegend": true, "type": "box", "x": ["Central Venous Catheter-Related Blood Stream Infection", "Central Venous Catheter-Related Blood Stream Infection", "Central Venous Catheter-Related Blood Stream Infection", "Central Venous Catheter-Related Blood Stream Infection", "Central Venous Catheter-Related Blood Stream Infection", "Central Venous Catheter-Related Blood Stream Infection", "Central Venous Catheter-Related Blood Stream Infection", "Central Venous Catheter-Related Blood Stream Infection", "Central Venous Catheter-Related Blood Stream Infection", "Central Venous Catheter-Related Blood Stream Infection", "Central Venous Catheter-Related Blood Stream Infection"], "x0": " ", "xaxis": "x", "y": [22.78, 21.7, 19.66, 11.85, 11.42, 10.18, 7.75, 4.43, 4.1, 4.05, 3.61], "y0": " ", "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "PSIDescription=%{x}<br>ObsRate=%{y}", "legendgroup": "PSIDescription=Postoperative Wound Dehiscence", "marker": {"color": "#FB0D0D"}, "name": "Postoperative Wound Dehiscence", "notched": false, "offsetgroup": "PSIDescription=Postoperative Wound Dehiscence", "orientation": "v", "showlegend": true, "type": "box", "x": ["Postoperative Wound Dehiscence", "Postoperative Wound Dehiscence", "Postoperative Wound Dehiscence", "Postoperative Wound Dehiscence", "Postoperative Wound Dehiscence", "Postoperative Wound Dehiscence", "Postoperative Wound Dehiscence", "Postoperative Wound Dehiscence", "Postoperative Wound Dehiscence", "Postoperative Wound Deh ...
#                         {"boxmode": "group", "height": 700, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "w

# %% [markdown]
# From our box plot, we can see which events have the largest range over our 10-year span of data. **Central Venous Catheter-Related Blood Stream Infection** & **Accidental Puncture or Laceration** have the highest and from looking back at our line chart earlier we can see these both experienced the most significant decrease since 2005.

# %% [markdown]
# # County Analysis:
# Now that we have a good knowledge of our data as a whole, we will dig in to the numbers further and uncover what counties are driving the events for the state.

# %%
# Grouping the data by County and summing ObsRate.

advobs = adv_county.groupby('County')[['ObsRate']] \
         .sum() \
         .reset_index() \
         .sort_values('ObsRate', ascending=False)

# Plotting.

fig = px.bar(advobs, x='County', y='ObsRate', color='County')

# Layout adjustments.

fig.update_layout(title='Observed Rate by County', xaxis_title='', 
                  yaxis_title='Count per 100K Population')

fig.for_each_trace(lambda t: t.update(name=t.name.replace("County=","")))

fig.show()
# Out:
# <div>
#
#
#             <div id="d439e37c-97a4-4096-b228-2d436acd59f4" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d439e37c-97a4-4096-b228-2d436acd59f4")) {
#                     Plotly.newPlot(
#                         'd439e37c-97a4-4096-b228-2d436acd59f4',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Lake", "marker": {"color": "#636efa"}, "name": "Lake", "offsetgroup": "County=Lake", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Lake"], "xaxis": "x", "y": [1756.6399999999996], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Tuolumne", "marker": {"color": "#EF553B"}, "name": "Tuolumne", "offsetgroup": "County=Tuolumne", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Tuolumne"], "xaxis": "x", "y": [1422.48], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Amador", "marker": {"color": "#00cc96"}, "name": "Amador", "offsetgroup": "County=Amador", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Amador"], "xaxis": "x", "y": [1298.1000000000001], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Calaveras", "marker": {"color": "#ab63fa"}, "name": "Calaveras", "offsetgroup": "County=Calaveras", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Calaveras"], "xaxis": "x", "y": [1265.7600000000002], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Napa", "marker": {"color": "#FFA15A"}, "name": "Napa", "offsetgroup": "County=Napa", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Napa"], "xaxis": "x", "y": [1238.9899999999998], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Mendocino", "marker": {"color": "#19d3f3"}, "name": "Mendocino", "offsetgroup": "County=Mendocino", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Mendocino"], "xaxis": "x", "y": [1196.29], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Shasta", "marker": {"color": "#FF6692"}, "name": "Shasta", "offsetgroup": "County=Shasta", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Shasta"], "xaxis": "x", "y": [1182.8700000000003], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Stanislaus", "marker": {"color": "#B6E880"}, "name": "Stanislaus", "offsetgroup": "County=Stanislaus", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Stanislaus"], "xaxis": "x", "y": [1154.36], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Nevada", "marker": {"color": "#FF97FF"}, "name": "Nevada", "offsetgroup": "County=Nevada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Nevada"], "xaxis": "x", "y": [1130.76], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Glenn", "marker": {"color": "#FECB52"}, "name": "Glenn", "offsetgroup": "County=Glenn", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Glenn"], "xaxis": "x", "y": [1128.7], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Kern", "marker": {"color": "#636efa"}, "name": "Kern", "offsetgroup": "County=Kern", "orientation": "v", "showlegend": true, "textpo ...

# %% [markdown]
# Immediately we can see the counties that have the highest total obs rate over the 10 year span that we were given in the data. **Lake County** especially is an outlier from the rest of the state. Let's look at this by year in a line plot and see if we can spot it and others as an outlier.

# %%
# Grouping by Year & County and summing the ObsRate.
# Leaving 'Statewide' in to be able to compare against individual counties.

advtime = adv.groupby(['Year', 'County'])[['ObsRate']] \
          .sum() \
          .reset_index() \
          .sort_values(['County', 'Year'])

# Plotting.

fig = px.line(advtime, x='Year', y='ObsRate', color='County')

# Layout adjustments.

fig.update_layout(title='Adverse Events Timeline by County', xaxis_title='', 
                  yaxis_title = 'Count per 100K Population')

fig.for_each_trace(lambda t: t.update(name=t.name.replace("County=", "")))

fig.show()
# Out:
# <div>
#
#
#             <div id="5b8b2d25-2209-4191-b780-8e03fe8678ef" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5b8b2d25-2209-4191-b780-8e03fe8678ef")) {
#                     Plotly.newPlot(
#                         '5b8b2d25-2209-4191-b780-8e03fe8678ef',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "County=Alameda<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Alameda", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Alameda", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [97.99, 94.95, 92.4, 76.72999999999999, 72.2, 69.91999999999999, 73.22, 67.72, 56.61, 57.89, 38.980000000000004], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "County=Amador<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Amador", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Amador", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [122.17999999999999, 139.87, 138.01, 139.16000000000003, 147.95, 97.72999999999999, 88.17, 88.91999999999999, 93.02000000000001, 129.43, 113.66], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "County=Butte<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Butte", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Butte", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [130.06, 124.28999999999999, 113.55000000000001, 101.31, 103.09, 100.84, 97.9, 99.67, 94.25999999999999, 71.03999999999999, 69.81], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "County=Calaveras<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Calaveras", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Calaveras", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [158.70999999999998, 163.93, 156.99, 105.14999999999999, 100.34, 103.25999999999999, 144.61, 119.69, 90.31, 56.56, 66.21], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "County=Colusa<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Colusa", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "Colusa", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [110.68, 109.00999999999999, 80.88, 47.01, 106.96, 138.93, 46.040000000000006, 35.980000000000004, 53.650000000000006, 96.16, 45.25], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "County=Contra Costa<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Contra Costa", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "Contra Costa", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [121.78000000000002, 122.23999999999998, 109.82000000000001, 88.32, 83.86, 83.88, 82.41999999999999, 74.12, 72.33, 60.32, 48.85], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "County=Del Norte<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Del Norte", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "lines", "name": "Del Norte", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [90.63, 122.41, 120.99000000000001, 93.75, 71.04, 84.41, 70.77000000000001, 50.660000000000004, 17.08, 38.04, 22.66], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "County=El Dorado<br>Year=%{x}<br>ObsRate=%{y}", "legendgroup": "County=El Dorado", "line": {"color": "#B6E880", "dash": "solid"}, "mode": "lines", "name": "El Dorado", "showlegend": true, "type": "scatter", "x": [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "xaxis": "x", "y": [125.81, 125.68, 119.97999999999999, 108.34, 99.05, 98.88, 75.63, 78.28999999999999, 68.89, 71.61, 61.93], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "County=Fresno<br>Y ...

# %% [markdown]
# This may seem too chaotic at a glance - but with  Plotly we can isolate our highest counties in the previous graph *or* compare specific counties we're interested in to the **Statewide** numbers, then we can begin to see trends in the data.

# %%
# Plotting.

fig = px.strip(adv, x='PSIDescription', y='ObsRate', color='County', 
               animation_frame='Year')

# Layout adjustments.

fig.update_layout(title='Observed Rate by County', xaxis_title='',
                 yaxis_title='Count per 100K Population', height=800)

fig.show()
# Out:
# <div>
#
#
#             <div id="85d9a239-f453-4dbe-87ab-3e6506be8173" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("85d9a239-f453-4dbe-87ab-3e6506be8173")) {
#                     Plotly.newPlot(
#                         '85d9a239-f453-4dbe-87ab-3e6506be8173',
#                         [{"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoverlabel": {"namelength": 0}, "hoveron": "points", "hovertemplate": "County=Statewide<br>Year=2005<br>PSIDescription=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Statewide", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa"}, "name": "County=Statewide", "offsetgroup": "County=Statewide", "orientation": "v", "pointpos": 0, "showlegend": true, "type": "box", "x": ["Retained Surgical Item or Unretrieved Device Fragment", "Iatrogenic Pneumothorax", "Central Venous Catheter-Related Blood Stream Infection", "Postoperative Wound Dehiscence", "Accidental Puncture or Laceration", "Transfusion Reaction", "Perioperative Hemorrhage or Hematoma"], "x0": " ", "xaxis": "x", "y": [1.21, 6.13, 22.78, 1.63, 32.96, 0.07, 34.37], "y0": " ", "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoverlabel": {"namelength": 0}, "hoveron": "points", "hovertemplate": "County=Alameda<br>Year=2005<br>PSIDescription=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Alameda", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B"}, "name": "County=Alameda", "offsetgroup": "County=Alameda", "orientation": "v", "pointpos": 0, "showlegend": true, "type": "box", "x": ["Retained Surgical Item or Unretrieved Device Fragment", "Iatrogenic Pneumothorax", "Central Venous Catheter-Related Blood Stream Infection", "Postoperative Wound Dehiscence", "Accidental Puncture or Laceration", "Transfusion Reaction", "Perioperative Hemorrhage or Hematoma"], "x0": " ", "xaxis": "x", "y": [1.63, 6.99, 22.68, 1.54, 32.76, 0.0, 32.39], "y0": " ", "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoverlabel": {"namelength": 0}, "hoveron": "points", "hovertemplate": "County=Amador<br>Year=2005<br>PSIDescription=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Amador", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#00cc96"}, "name": "County=Amador", "offsetgroup": "County=Amador", "orientation": "v", "pointpos": 0, "showlegend": true, "type": "box", "x": ["Retained Surgical Item or Unretrieved Device Fragment", "Iatrogenic Pneumothorax", "Central Venous Catheter-Related Blood Stream Infection", "Postoperative Wound Dehiscence", "Accidental Puncture or Laceration", "Transfusion Reaction", "Perioperative Hemorrhage or Hematoma"], "x0": " ", "xaxis": "x", "y": [0.0, 6.43, 35.37, 0.0, 41.8, 0.0, 38.58], "y0": " ", "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoverlabel": {"namelength": 0}, "hoveron": "points", "hovertemplate": "County=Butte<br>Year=2005<br>PSIDescription=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Butte", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#ab63fa"}, "name": "County=Butte", "offsetgroup": "County=Butte", "orientation": "v", "pointpos": 0, "showlegend": true, "type": "box", "x": ["Retained Surgical Item or Unretrieved Device Fragment", "Iatrogenic Pneumothorax", "Central Venous Catheter-Related Blood Stream Infection", "Postoperative Wound Dehiscence", "Accidental Puncture or Laceration", "Transfusion Reaction", "Perioperative Hemorrhage or Hematoma"], "x0": " ", "xaxis": "x", "y": [2.42, 9.68, 31.46, 3.02, 38.11, 0.0, 45.37], "y0": " ", "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoverlabel": {"namelength": 0}, "hoveron": "points", "hovertemplate": "County=Calaveras<br>Year=2005<br>PSIDescription=%{x}<br>ObsRate=%{y}", "legendgroup": "County=Calaveras", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#FFA15A"}, "name": "County=Calaveras", "offsetgroup": "County=Calaveras", "orientation": "v", "pointpos": 0, "showlegend": true, "type": "box", "x": ["Retained Surgical Item or Unretrieved Device Fragment", "Iatrogenic Pneumothorax", "Central Venous Catheter-Related Blood  ...

# %% [markdown]
# From this, we can see that **Lake County** was well above the average distribution most years for **Perioperative Hemorrhage** or **Hematoma and Accidental Puncture or Laceration**. Prior to *2009*, **Mariposa** was high in the events reported as well until it saw a major drop in its count of events.

# %% [markdown]
# # Mapping County Event Rates:
# Now that we've done some detailed analyses of our data, let's put what we've found on a map to further visualize the distribution of these events within the state.

# %%
# Creating a latitude and longitude map to be able to add these values in our data.

lat_map = {'Alameda' : '37.6017', 'Amador' : '38.3489', 'Butte' : '39.6254', 'Calaveras' : '38.1960', 'Colusa' : '39.1041',
       'Contra Costa' : '37.8534', 'Del Norte' : '41.7076', 'El Dorado' : '38.7426', 'Fresno' : '36.9859', 'Glenn' : '39.6438',
       'Humboldt' : '40.7450', 'Imperial' : '33.0114', 'Inyo' : '36.3092', 'Kern' : '35.4937', 'Kings' : '36.0988', 'Lake' : '39.0840', 'Lassen' : '40.5394',
       'Los Angeles' : '34.0522', 'Madera' : '37.2519', 'Marin' : '38.0834', 'Mariposa' : '37.4894', 'Mendocino' : '39.5500',
       'Merced' : '37.2010', 'Modoc' : '41.4565', 'Mono' : '37.9219', 'Monterey' : '36.3136', 'Napa' : '38.5025', 'Nevada' : '39.1347', 'Orange' : '33.7175',
       'Placer' : '39.0916', 'Plumas' : '39.9927', 'Riverside' : '33.9533', 'Sacramento' : '38.4747', 'San Benito' : '36.5761',
       'San Bernardino' : '34.9592', 'San Diego' : '32.7157', 'San Francisco' : '37.7749', 'San Joaquin' : '37.9176',
       'San Luis Obispo' : '35.3102', 'San Mateo' : '37.4337', 'Santa Barbara' : '34.4208', 'Santa Clara' : '37.3337',
       'Santa Cruz' : '37.0454', 'Shasta' : '40.7909', 'Siskiyou' : '41.7743', 'Solano' : '38.3105', 'Sonoma' : '38.5780',
       'Stanislaus' : '37.5091', 'Sutter' : '39.0220', 'Tehama' : '40.0982', 'Trinity' : '40.6329', 'Tulare' : '36.1342', 'Tuolumne' : '38.0297',
       'Ventura' : '34.3705', 'Yolo' : '38.7646', 'Yuba' : '39.2547'}

lon_map = {'Alameda' : '-121.7195', 'Amador' : '-120.7741', 'Butte' : '-121.5370', 'Calaveras' : '-120.6805', 'Colusa' : '-122.2654',
       'Contra Costa' : '-121.9018', 'Del Norte' : '-123.9660', 'El Dorado' : '-120.4358', 'Fresno' : '-119.2321', 'Glenn' : '-122.4467',
       'Humboldt' : '-123.8695', 'Imperial' : '-115.4734', 'Inyo' : '-117.5496', 'Kern' : '-118.8597', 'Kings' : '-119.8815', 'Lake' : '-122.8084', 'Lassen' : '-120.7120',
       'Los Angeles' : '-118.2437', 'Madera' : '-119.6963', 'Marin' : '-122.7633', 'Mariposa' : '-119.9679', 'Mendocino' : '-123.4384',
       'Merced' : '-120.7120', 'Modoc' : '-120.6294', 'Mono' : '-118.9529', 'Monterey' : '-121.3542', 'Napa' : '-122.2654', 'Nevada' : '-121.1710', 'Orange' : '-117.8311',
       'Placer' : '-120.8039', 'Plumas' : '-120.8039', 'Riverside' : '-117.3961', 'Sacramento' : '-121.3542', 'San Benito' : '-120.9876',
       'San Bernardino' : '-116.4194', 'San Diego' : '-117.1611', 'San Francisco' : '-122.4194', 'San Joaquin' : '-121.1710',
       'San Luis Obispo' : '-120.4358', 'San Mateo' : '-122.4014', 'Santa Barbara' : '-119.6982', 'Santa Clara' : '-121.8907',
       'Santa Cruz' : '-121.9580', 'Shasta' : '-121.8474', 'Siskiyou' : '-122.5770', 'Solano' : '-121.9018', 'Sonoma' : '-122.9888',
       'Stanislaus' : '-120.9876', 'Sutter' : '-121.6739', 'Tehama' : '-122.1746', 'Trinity' : '-123.0623', 'Tulare' : '-118.8597', 'Tuolumne' : '-119.9741',
       'Ventura' : '-119.1391', 'Yolo' : '-121.9018', 'Yuba' : '-121.3999'}

# %%
# Assigning lat & lon to counties.

adv_county['Latitude']=adv_county['County'].map(lat_map)
adv_county['Longitude']=adv_county['County'].map(lon_map)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Grouping by Year & County and summing ObsRate.

advmap = adv_county.groupby(['Year', 'County', 'Latitude', 'Longitude'])[['ObsRate']] \
         .sum() \
         .reset_index() \
         .sort_values(['County', 'Year'])

# %%
# Plotting.

fig = px.scatter_geo(data_frame=advmap, scope='usa',lat='Latitude',lon='Longitude',
                     color='County', size='ObsRate', animation_frame='Year', size_max = 20)

# Layout adjustments.

fig.update_layout(title_text = 'California Event Rates by County')

fig.show()
# Out:
# <div>
#
#
#             <div id="df823bf0-4bf2-4aea-8413-102ae22a0c70" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("df823bf0-4bf2-4aea-8413-102ae22a0c70")) {
#                     Plotly.newPlot(
#                         'df823bf0-4bf2-4aea-8413-102ae22a0c70',
#                         [{"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Alameda<br>Year=2005<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["37.6017"], "legendgroup": "County=Alameda", "lon": ["-121.7195"], "marker": {"color": "#636efa", "size": [97.99], "sizemode": "area", "sizeref": 0.58555}, "name": "County=Alameda", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Amador<br>Year=2005<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["38.3489"], "legendgroup": "County=Amador", "lon": ["-120.7741"], "marker": {"color": "#EF553B", "size": [122.17999999999999], "sizemode": "area", "sizeref": 0.58555}, "name": "County=Amador", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Butte<br>Year=2005<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["39.6254"], "legendgroup": "County=Butte", "lon": ["-121.5370"], "marker": {"color": "#00cc96", "size": [130.06], "sizemode": "area", "sizeref": 0.58555}, "name": "County=Butte", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Calaveras<br>Year=2005<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["38.1960"], "legendgroup": "County=Calaveras", "lon": ["-120.6805"], "marker": {"color": "#ab63fa", "size": [158.70999999999998], "sizemode": "area", "sizeref": 0.58555}, "name": "County=Calaveras", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Colusa<br>Year=2005<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["39.1041"], "legendgroup": "County=Colusa", "lon": ["-122.2654"], "marker": {"color": "#FFA15A", "size": [110.68], "sizemode": "area", "sizeref": 0.58555}, "name": "County=Colusa", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Contra Costa<br>Year=2005<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["37.8534"], "legendgroup": "County=Contra Costa", "lon": ["-121.9018"], "marker": {"color": "#19d3f3", "size": [121.78000000000002], "sizemode": "area", "sizeref": 0.58555}, "name": "County=Contra Costa", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Del Norte<br>Year=2005<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["41.7076"], "legendgroup": "County=Del Norte", "lon": ["-123.9660"], "marker": {"color": "#FF6692", "size": [90.63], "sizemode": "area", "sizeref": 0.58555}, "name": "County=Del Norte", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=El Dorado<br>Year=2005<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["38.7426"], "legendgroup": "County=El Dorado", "lon": ["-120.4358"], "marker": {"color": "#B6E880", "size": [125.81], "sizemode": "area", "sizeref": 0.58555}, "name": "County=El Dorado", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Fresno<br>Year=2005<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["36.9859"], "legendgroup": "County=Fresno", "lon": ["-119.2321"], "marker": {"color": "#FF97FF", "size": [101.6], "sizemode": "area", "sizeref": 0.58555}, "name": "County=Fresno", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Glenn<br>Year=2005<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["39.6438"], "legendgroup": "County=Glenn", "lon": ["-122.4467"], "marker": {"color": "#FECB52", "size": [127.85999999999999], "sizemode": "area", "sizeref": 0.58555}, "name": "County=Glenn", "showlegend ...

# %% [markdown]
# By making use of the animation, we can quickly visualize how the adverse event rate per county has changed over our time period. The animation bar can also be used as a slider to focus on each year by itself

# %%
# Grouping totals from 2005-2015 by County.

advmaptotal = adv_county.groupby(['County', 'Latitude', 'Longitude'])[['ObsRate']] \
             .sum() \
             .reset_index() \
             .sort_values('County')

# Plotting.

fig = px.scatter_geo(data_frame=advmaptotal, scope='usa',lat='Latitude',lon='Longitude',
                     color='County', size='ObsRate', size_max = 20, 
                     color_continuous_scale='Sunsetdark')

# Layout adjustments.

fig.update_layout(title_text = 'California Event Rates by County: Total (2005-2015)')

fig.for_each_trace(lambda t: t.update(name=t.name.replace("County=", "")))

fig.show()
# Out:
# <div>
#
#
#             <div id="afab54bb-37a4-4c44-997e-08cc249f8274" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("afab54bb-37a4-4c44-997e-08cc249f8274")) {
#                     Plotly.newPlot(
#                         'afab54bb-37a4-4c44-997e-08cc249f8274',
#                         [{"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Alameda<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["37.6017"], "legendgroup": "County=Alameda", "lon": ["-121.7195"], "marker": {"color": "#636efa", "size": [798.6099999999998], "sizemode": "area", "sizeref": 4.3915999999999995}, "name": "Alameda", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Amador<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["38.3489"], "legendgroup": "County=Amador", "lon": ["-120.7741"], "marker": {"color": "#EF553B", "size": [1298.1000000000001], "sizemode": "area", "sizeref": 4.3915999999999995}, "name": "Amador", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Butte<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["39.6254"], "legendgroup": "County=Butte", "lon": ["-121.5370"], "marker": {"color": "#00cc96", "size": [1105.82], "sizemode": "area", "sizeref": 4.3915999999999995}, "name": "Butte", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Calaveras<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["38.1960"], "legendgroup": "County=Calaveras", "lon": ["-120.6805"], "marker": {"color": "#ab63fa", "size": [1265.7600000000002], "sizemode": "area", "sizeref": 4.3915999999999995}, "name": "Calaveras", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Colusa<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["39.1041"], "legendgroup": "County=Colusa", "lon": ["-122.2654"], "marker": {"color": "#FFA15A", "size": [870.5500000000002], "sizemode": "area", "sizeref": 4.3915999999999995}, "name": "Colusa", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Contra Costa<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["37.8534"], "legendgroup": "County=Contra Costa", "lon": ["-121.9018"], "marker": {"color": "#19d3f3", "size": [947.9399999999998], "sizemode": "area", "sizeref": 4.3915999999999995}, "name": "Contra Costa", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Del Norte<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["41.7076"], "legendgroup": "County=Del Norte", "lon": ["-123.9660"], "marker": {"color": "#FF6692", "size": [782.44], "sizemode": "area", "sizeref": 4.3915999999999995}, "name": "Del Norte", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=El Dorado<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["38.7426"], "legendgroup": "County=El Dorado", "lon": ["-120.4358"], "marker": {"color": "#B6E880", "size": [1034.0900000000001], "sizemode": "area", "sizeref": 4.3915999999999995}, "name": "El Dorado", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Fresno<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["36.9859"], "legendgroup": "County=Fresno", "lon": ["-119.2321"], "marker": {"color": "#FF97FF", "size": [954.9399999999998], "sizemode": "area", "sizeref": 4.3915999999999995}, "name": "Fresno", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=Glenn<br>ObsRate=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}", "lat": ["39.6438"], "legendgroup": "County=Glenn", "lon": ["-122.4467"], "marker": {"color": "#FECB52", "size": [1128.7], "sizemode": "area", "sizeref": 4.3915999999999995}, "name": "Glenn", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hoverl ...

# %% [markdown]
# # Conclusion:
# We aimed to answer a few questions with this data that I addressed in the beginning. By slicing up the data and making use of visualizations, we were able to answer these questions.
#
# From our analysis we found:
# - The overall rate of adverse events more than **halved** from *2005-2015*.
# - **Perioperative Hemorrhage / Hematoma** and **Accidental Puncture / Laceration** are the events occuring most commonly from our data.
# - **Lake County** has the highest count of events per 100K population from our data.
